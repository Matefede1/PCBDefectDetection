# %%
# !nvidia-smi
# Out:
# Tue Jan  9 16:36:29 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 545.36                 Driver Version: 546.33       CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 3050 ...    On  | 00000000:01:00.0  On |                  N/A |
# | N/A   58C    P3              10W /  60W |   1767MiB /  4096MiB |     37%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
#!git clone https://github.com/WongKinYiu/yolov7.git

# %%
#%cd ..
# %cd content/yolov7

# %%
# !pip install -r requirements.txt

# %%
# %cd ..

# %%
import os

# %%
# %pwd

# %%
#train_img_path= '/home/diegotamborelli/code/Matefede1/PCBDefectDetection/PCBDefectDetection/content/drive/MyDrive/yoloTest/images/train'
#val_img_path= '/home/diegotamborelli/code/Matefede1/PCBDefectDetection/PCBDefectDetection/content/drive/MyDrive/yoloTest/images/val'



pwd = os.getcwd()
train_img_path= '../drive/MyDrive/yoloTest/images/train'
val_img_path= '../drive/MyDrive/yoloTest/images/val'

train_img_path = os.path.join( pwd, train_img_path)
val_img_path = os.path.join( pwd, val_img_path)

# %%
# %cd content/yolov7

# %%
# %pwd

# %%
#Reading Training images
with open('train.txt', 'a+') as f:
  img_list= os.listdir(train_img_path)
  for img in img_list:
    f.write(os.path.join(train_img_path,img+'\n'))
  print('Done')
# Out:
# Done

# %%
#Adressing validation set
with open('val.txt', 'a+') as f:
  img_list= os.listdir(val_img_path)
  for img in img_list:
    f.write(os.path.join(val_img_path,img+'\n'))
  print('Done')
# Out:
# Done

# %%
# %cp /home/diegotamborelli/code/Matefede1/PCBDefectDetection/PCBDefectDetection/content/yolov7/data/coco.yaml /home/diegotamborelli/code/Matefede1/PCBDefectDetection/PCBDefectDetection/content/yolov7/data/custom.yaml

# %%
# %cd /content/yolov7
# !wget "https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7.pt"

# %%
# %cp /home/diegotamborelli/code/Matefede1/PCBDefectDetection/PCBDefectDetection/content/yolov7/cfg/training/yolov7.yaml  /home/diegotamborelli/code/Matefede1/PCBDefectDetection/PCBDefectDetection/content/yolov7/cfg/training/custom_yolov7.yaml

# %%
# %pwd

# %%
# !python train.py --batch 16 --cfg cfg/training/custom_yolov7.yaml --epochs 5 --data /data/custom.yaml --weights 'yolov7.pt' --device 0
# Out:
# YOLOR 🚀 2024-1-9 torch 2.1.2+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4095.5MB)
#
# Namespace(weights='yolov7.pt', cfg='cfg/training/custom_yolov7.yaml', data='./data/custom.yaml', hyp='data/hyp.scratch.p5.yaml', epochs=5, batch_size=16, img_size=[640, 640], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='0', multi_scale=False, single_cls=False, adam=False, sync_bn=False, local_rank=-1, workers=8, project='runs/train', entity=None, name='exp', exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias='latest', freeze=[0], v5_metric=False, world_size=1, global_rank=-1, save_dir='runs/train/exp7', total_batch_size=16)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# !python detect.py --weights /content/yolov7/runs/train/exp/weights/best.pt --source /content/yolov7/01_missing_hole_20.jpg
